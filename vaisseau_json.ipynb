# %%
import requests
import pandas as pd

# %%
def import_vaisseau():
    r = requests.get("https://swapi.dev/api/starships")
    return r

# %%
def vaisseau_json():
    r = requests.get("https://swapi.dev/api/starships")
    jsonr = r.json()
    return jsonr

# %%
pd.DataFrame(vaisseau_json)
# Out:
#    count                                     next previous  \
# 0     36  https://swapi.dev/api/starships/?page=2     None
# 1     36  https://swapi.dev/api/starships/?page=2     None
# 2     36  https://swapi.dev/api/starships/?page=2     None
# 3     36  https://swapi.dev/api/starships/?page=2     None
# 4     36  https://swapi.dev/api/starships/?page=2     None
# 5     36  https://swapi.dev/api/starships/?page=2     None
# 6     36  https://swapi.dev/api/starships/?page=2     None
# 7     36  https://swapi.dev/api/starships/?page=2     None
# 8     36  https://swapi.dev/api/starships/?page=2     None
# 9     36  https://swapi.dev/api/starships/?page=2     None
#
#                                              results
# 0  {'name': 'CR90 corvette', 'model': 'CR90 corve...
# 1  {'name': 'Star Destroyer', 'model': 'Imperial ...
# 2  {'name': 'Sentinel-class landing craft', 'mode...
# 3  {'name': 'Death Star', 'model': 'DS-1 Orbital ...
# 4  {'name': 'Millennium Falcon', 'model': 'YT-130...
# 5  {'name': 'Y-wing', 'model': 'BTL Y-wing', 'man...
# 6  {'name': 'X-wing', 'model': 'T-65 X-wing', 'ma...
# 7  {'name': 'TIE Advanced x1', 'model': 'Twin Ion...
# 8  {'name': 'Executor', 'model': 'Executor-class ...
# 9  {'name': 'Rebel transport', 'model': 'GR-75 me...
